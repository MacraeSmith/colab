# %% [markdown]
# <a href="https://colab.research.google.com/github/MacraeSmith/helloAI/blob/main/Assignment3HyperParams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://blog.infuseai.io/run-a-full-tty-terminal-in-google-colab-without-colab-pro-2759b9f8a74a
# xterm may be helpful for speeding up some of the parts of this assignment ... see in class instruction on usage
#!pip install colab-xterm
#%load_ext colabxterm
# !git clone "https://github.com/kartoone/nn3"
# !git pull
# Out:
# Cloning into 'nn3'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 145 (delta 19), reused 17 (delta 8), pack-reused 109
# Receiving objects: 100% (145/145), 94.35 MiB | 28.73 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# fatal: not a git repository (or any of the parent directories): .git

# %%
# %cd nn3/src
# Out:
# /content/nn3/src

# %%
from network import Network
import mnist_loader
import numpy as np
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
net = Network([784, 30, 10])
print(np.shape(net.biases))
print(net.biases)
# Out:
# (2,)
# [array([[-0.16109334],
#        [-0.58108475],
#        [-1.36466617],
#        [ 0.05000352],
#        [-0.7211505 ],
#        [ 0.41802299],
#        [-0.05855623],
#        [-0.08027302],
#        [ 0.5146733 ],
#        [ 0.79879495],
#        [-1.47630334],
#        [-0.67652976],
#        [-0.57745693],
#        [-1.1451311 ],
#        [ 1.33965392],
#        [ 1.37156149],
#        [-0.07224263],
#        [ 0.24512109],
#        [ 1.46286469],
#        [-0.69862875],
#        [ 0.16528621],
#        [ 0.08712007],
#        [ 0.73241908],
#        [-1.50183124],
#        [-1.01168545],
#        [-1.02015449],
#        [ 0.27331583],
#        [-0.72153977],
#        [ 0.34673117],
#        [-0.0616273 ]]), array([[-1.07814387],
#        [ 0.56483516],
#        [ 0.59765878],
#        [ 0.43183771],
#        [ 1.95571273],
#        [ 1.40274202],
#        [ 0.4193428 ],
#        [-1.13921037],
#        [ 0.46526632],
#        [ 1.07300994]])]
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:1970: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape

# %%
import numpy as np

# finds the image that the network has the hardest time classifying
def findTroublesomeImage(test_data, net):
  worsti = -1
  worsta = 1.0
  for i,(x,y) in enumerate(test_data):
    a = net.feedforward(x)
    if np.max(a)<worsta:
      worsta = np.max(a)
      worsti = i
  print(worsta)
  print(worsti)
  return worsti

# %%
  from network import Network
  import mnist_loader
  import time

  training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
  configs = [[784,15,10], [784, 30, 10], [784, 100, 10], [784, 15, 15, 10], [784, 30, 30, 10], [784, 100, 100, 10]] # ADD THE REMAINING CONFIGS HERE!!!!training_times = []
  training_times = []
  accuracies = []

# %%
  for config in configs:
    print(config)
    start = time.time()
    net = Network(config)
    accuracies.append(net.SGD(training_data[0:len(training_data)], 30, 10, 3.0, test_data=test_data[0:len(test_data)]))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:len(test_data)], net)
    import matplotlib.pyplot as plt
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()
# repeat the above IN DIFFERENT CELLS (don't do it all in one cell, you will thank me later) for all the structural configurations
# Out:
# [784, 15, 10]
# Epoch 0: starting...training completed in 9.1s...measuring accuracy...9025 / 10000 in 0.33s
# Epoch 1: starting...training completed in 6.03s...measuring accuracy...9204 / 10000 in 0.31s
# Epoch 2: starting...training completed in 6.11s...measuring accuracy...9241 / 10000 in 0.3s
# Epoch 3: starting...training completed in 6.05s...measuring accuracy...9259 / 10000 in 0.33s
# Epoch 4: starting...training completed in 6.0s...measuring accuracy...9267 / 10000 in 0.36s
# Epoch 5: starting...training completed in 5.97s...measuring accuracy...9236 / 10000 in 0.3s
# Epoch 6: starting...training completed in 6.04s...measuring accuracy...9286 / 10000 in 0.3s
# Epoch 7: starting...training completed in 5.95s...measuring accuracy...9229 / 10000 in 0.42s
# Epoch 8: starting...training completed in 5.99s...measuring accuracy...9270 / 10000 in 0.32s
# Epoch 9: starting...training completed in 6.05s...measuring accuracy...9290 / 10000 in 0.32s
# Epoch 10: starting...training completed in 5.88s...measuring accuracy...9296 / 10000 in 0.32s
# Epoch 11: starting...training completed in 6.05s...measuring accuracy...9275 / 10000 in 0.32s
# Epoch 12: starting...training completed in 5.99s...measuring accuracy...9306 / 10000 in 0.31s
# Epoch 13: starting...training completed in 5.95s...measuring accuracy...9307 / 10000 in 0.3s
# Epoch 14: starting...training completed in 6.06s...measuring accuracy...9328 / 10000 in 0.39s
# Epoch 15: starting...training completed in 5.95s...measuring accuracy...9311 / 10000 in 0.32s
# Epoch 16: starting...training completed in 5.95s...measuring accuracy...9335 / 10000 in 0.35s
# Epoch 17: starting...training completed in 5.99s...measuring accuracy...9346 / 10000 in 0.32s
# Epoch 18: starting...training completed in 5.99s...measuring accuracy...9318 / 10000 in 0.3s
# Epoch 19: starting...training completed in 6.1s...measuring accuracy...9346 / 10000 in 0.3s
# Epoch 20: starting...training completed in 5.91s...measuring accuracy...9343 / 10000 in 0.39s
# Epoch 21: starting...training completed in 5.96s...measuring accuracy...9345 / 10000 in 0.32s
# Epoch 22: starting...training completed in 6.4s...measuring accuracy...9362 / 10000 in 0.3s
# Epoch 23: starting...training completed in 6.09s...measuring accuracy...9347 / 10000 in 0.33s
# Epoch 24: starting...training completed in 6.07s...measuring accuracy...9314 / 10000 in 0.36s
# Epoch 25: starting...training completed in 5.92s...measuring accuracy...9343 / 10000 in 0.35s
# Epoch 26: starting...training completed in 5.97s...measuring accuracy...9323 / 10000 in 0.33s
# Epoch 27: starting...training completed in 6.11s...measuring accuracy...9358 / 10000 in 0.34s
# Epoch 28: starting...training completed in 5.93s...measuring accuracy...9344 / 10000 in 0.36s
# Epoch 29: starting...training completed in 5.96s...measuring accuracy...9280 / 10000 in 0.36s
# 193.49233436584473
# 0.00337880134195394
# 4212
# [784, 30, 10]
# Epoch 0: starting...training completed in 8.4s...measuring accuracy...9123 / 10000 in 0.36s
# Epoch 1: starting...training completed in 8.28s...measuring accuracy...9219 / 10000 in 0.33s
# Epoch 2: starting...training completed in 8.34s...measuring accuracy...9327 / 10000 in 0.36s
# Epoch 3: starting...training completed in 8.32s...measuring accuracy...9342 / 10000 in 0.34s
# Epoch 4: starting...training completed in 8.31s...measuring accuracy...9351 / 10000 in 0.32s
# Epoch 5: starting...training completed in 8.35s...measuring accuracy...9415 / 10000 in 0.41s
# Epoch 6: starting...training completed in 8.32s...measuring accuracy...9417 / 10000 in 0.36s
# Epoch 7: starting...training completed in 8.3s...measuring accuracy...9411 / 10000 in 0.36s
# Epoch 8: starting...training completed in 8.42s...measuring accuracy...9454 / 10000 in 0.32s
# Epoch 9: starting...training completed in 8.45s...measuring accuracy...9465 / 10000 in 0.36s
# Epoch 10: starting...training completed in 8.3s...measuring accuracy...9489 / 10000 in 0.41s
# Epoch 11: starting...training completed in 8.39s...measuring accuracy...9481 / 10000 in 0.34s
# Epoch 12: starting...training completed in 8.5s...measuring accuracy...9487 / 10000 in 0.32s
# Epoch 13: starting...training completed in 8.5s...measuring accuracy...9467 / 10000 in 0.45s
# Epoch 14: starting...training completed in 8.27s...measuring accuracy...9491 / 10000 in 0.34s
# Epoch 15: starting...training completed in 8.35s...measuring accuracy...9494 / 10000 in 0.38s
# Epoch 16: starting...training completed in 8.34s...measuring accuracy...9491 / 10000 in 0.32s
# Epoch 17: starting...training completed in 8.4s...measuring accuracy...9499 / 10000 in 0.35s
# Epoch 18: starting...training completed in 8.31s...measuring accuracy...9497 / 10000 in 0.35s
# Epoch 19: starting...training completed in 8.35s...measuring accuracy...9476 / 10000 in 0.35s
# Epoch 20: starting...training completed in 8.27s...measuring accuracy...9471 / 10000 in 0.4s
# Epoch 21: starting...training completed in 8.47s...measuring accuracy...9469 / 10000 in 0.35s
# Epoch 22: starting...training completed in 8.36s...measuring accuracy...9490 / 10000 in 0.33s
# Epoch 23: starting...training completed in 8.6s...measuring accuracy...9494 / 10000 in 0.32s
# Epoch 24: starting...training completed in 8.24s...measuring accuracy...9491 / 10000 in 0.34s
# Epoch 25: starting...training completed in 8.62s...measuring accuracy...9503 / 10000 in 0.34s
# Epoch 26: starting...training completed in 8.37s...measuring accuracy...9497 / 10000 in 0.36s
# Epoch 27: starting...training completed in 8.36s...measuring accuracy...9499 / 10000 in 0.38s
# Epoch 28: starting...training completed in 8.34s...measuring accuracy...9497 / 10000 in 0.38s
# Epoch 29: starting...training completed in 8.42s...measuring accuracy...9505 / 10000 in 0.37s
# 261.9679706096649
# 0.0017477074999597427
# 6071
# [784, 100, 10]
# Epoch 0: starting...training completed in 20.34s...measuring accuracy...4222 / 10000 in 0.45s
# Epoch 1: starting...training completed in 20.55s...measuring accuracy...7365 / 10000 in 0.42s
# Epoch 2: starting...training completed in 20.48s...measuring accuracy...7495 / 10000 in 0.45s
# Epoch 3: starting...training completed in 20.56s...measuring accuracy...8281 / 10000 in 0.42s
# Epoch 4: starting...training completed in 20.45s...measuring accuracy...8329 / 10000 in 0.51s
# Epoch 5: starting...training completed in 20.49s...measuring accuracy...8392 / 10000 in 0.44s
# Epoch 6: starting...training completed in 20.34s...measuring accuracy...8418 / 10000 in 0.49s
# Epoch 7: starting...training completed in 20.39s...measuring accuracy...8422 / 10000 in 0.45s
# Epoch 8: starting...training completed in 20.77s...measuring accuracy...8478 / 10000 in 0.43s
# Epoch 9: starting...training completed in 20.57s...measuring accuracy...8463 / 10000 in 0.42s
# Epoch 10: starting...training completed in 20.35s...measuring accuracy...8487 / 10000 in 0.47s
# Epoch 11: starting...training completed in 20.41s...measuring accuracy...8512 / 10000 in 0.42s
# Epoch 12: starting...training completed in 20.62s...measuring accuracy...8520 / 10000 in 0.44s
# Epoch 13: starting...training completed in 20.4s...measuring accuracy...8505 / 10000 in 0.5s
# Epoch 14: starting...training completed in 20.48s...measuring accuracy...8534 / 10000 in 0.43s
# Epoch 15: starting...training completed in 20.58s...measuring accuracy...8511 / 10000 in 0.44s
# Epoch 16: starting...training completed in 20.6s...measuring accuracy...8524 / 10000 in 0.44s
# Epoch 17: starting...training completed in 20.41s...measuring accuracy...8551 / 10000 in 0.43s
# Epoch 18: starting...training completed in 20.39s...measuring accuracy...8530 / 10000 in 0.47s
# Epoch 19: starting...training completed in 20.56s...measuring accuracy...8528 / 10000 in 0.46s
# Epoch 20: starting...training completed in 20.34s...measuring accuracy...8535 / 10000 in 0.45s
# Epoch 21: starting...training completed in 20.44s...measuring accuracy...8544 / 10000 in 0.45s
# Epoch 22: starting...training completed in 20.54s...measuring accuracy...8536 / 10000 in 0.5s
# Epoch 23: starting...training completed in 20.41s...measuring accuracy...8536 / 10000 in 0.45s
# Epoch 24: starting...training completed in 20.56s...measuring accuracy...8538 / 10000 in 0.43s
# Epoch 25: starting...training completed in 20.78s...measuring accuracy...8543 / 10000 in 0.47s
# Epoch 26: starting...training completed in 20.53s...measuring accuracy...8556 / 10000 in 0.5s
# Epoch 27: starting...training completed in 20.59s...measuring accuracy...8541 / 10000 in 0.45s
# Epoch 28: starting...training completed in 20.48s...measuring accuracy...8544 / 10000 in 0.43s
# Epoch 29: starting...training completed in 20.34s...measuring accuracy...8535 / 10000 in 0.44s
# 628.3819026947021
# 8.788156646850464e-08
# 3379
# [784, 15, 15, 10]
# Epoch 0: starting...training completed in 8.11s...measuring accuracy...8980 / 10000 in 0.42s
# Epoch 1: starting...training completed in 8.2s...measuring accuracy...9092 / 10000 in 0.43s
# Epoch 2: starting...training completed in 8.09s...measuring accuracy...9054 / 10000 in 0.43s
# Epoch 3: starting...training completed in 8.3s...measuring accuracy...9205 / 10000 in 0.43s
# Epoch 4: starting...training completed in 8.42s...measuring accuracy...9190 / 10000 in 0.41s
# Epoch 5: starting...training completed in 8.09s...measuring accuracy...9077 / 10000 in 0.42s
# Epoch 6: starting...training completed in 8.07s...measuring accuracy...9254 / 10000 in 0.42s
# Epoch 7: starting...training completed in 8.35s...measuring accuracy...9264 / 10000 in 0.41s
# Epoch 8: starting...training completed in 8.22s...measuring accuracy...9291 / 10000 in 0.43s
# Epoch 9: starting...training completed in 8.31s...measuring accuracy...9289 / 10000 in 0.57s
# Epoch 10: starting...training completed in 8.15s...measuring accuracy...9280 / 10000 in 0.49s
# Epoch 11: starting...training completed in 8.17s...measuring accuracy...9308 / 10000 in 0.41s
# Epoch 12: starting...training completed in 8.25s...measuring accuracy...9303 / 10000 in 0.42s
# Epoch 13: starting...training completed in 8.34s...measuring accuracy...9272 / 10000 in 0.41s
# Epoch 14: starting...training completed in 8.25s...measuring accuracy...9311 / 10000 in 0.41s
# Epoch 15: starting...training completed in 8.1s...measuring accuracy...9324 / 10000 in 0.43s
# Epoch 16: starting...training completed in 8.51s...measuring accuracy...9317 / 10000 in 0.43s
# Epoch 17: starting...training completed in 8.36s...measuring accuracy...9284 / 10000 in 0.46s
# Epoch 18: starting...training completed in 8.1s...measuring accuracy...9245 / 10000 in 0.41s
# Epoch 19: starting...training completed in 8.06s...measuring accuracy...9258 / 10000 in 0.43s
# Epoch 20: starting...training completed in 8.06s...measuring accuracy...9298 / 10000 in 0.42s
# Epoch 21: starting...training completed in 8.08s...measuring accuracy...9258 / 10000 in 0.4s
# Epoch 22: starting...training completed in 8.35s...measuring accuracy...9342 / 10000 in 0.44s
# Epoch 23: starting...training completed in 8.01s...measuring accuracy...9328 / 10000 in 0.42s
# Epoch 24: starting...training completed in 8.13s...measuring accuracy...9290 / 10000 in 0.42s
# Epoch 25: starting...training completed in 8.42s...measuring accuracy...9318 / 10000 in 0.43s
# Epoch 26: starting...training completed in 8.12s...measuring accuracy...9343 / 10000 in 0.4s
# Epoch 27: starting...training completed in 8.22s...measuring accuracy...9337 / 10000 in 0.41s
# Epoch 28: starting...training completed in 8.37s...measuring accuracy...9295 / 10000 in 0.4s
# Epoch 29: starting...training completed in 8.14s...measuring accuracy...9326 / 10000 in 0.51s
# 259.3000485897064
# 0.01670450310393574
# 195
# [784, 30, 30, 10]
# Epoch 0: starting...training completed in 10.8s...measuring accuracy...9035 / 10000 in 0.45s
# Epoch 1: starting...training completed in 10.87s...measuring accuracy...9210 / 10000 in 0.49s
# Epoch 2: starting...training completed in 10.81s...measuring accuracy...9229 / 10000 in 0.44s
# Epoch 3: starting...training completed in 10.78s...measuring accuracy...9348 / 10000 in 0.47s
# Epoch 4: starting...training completed in 10.85s...measuring accuracy...9375 / 10000 in 0.44s
# Epoch 5: starting...training completed in 10.9s...measuring accuracy...9365 / 10000 in 0.42s
# Epoch 6: starting...training completed in 10.87s...measuring accuracy...9423 / 10000 in 0.44s
# Epoch 7: starting...training completed in 10.92s...measuring accuracy...9458 / 10000 in 0.49s
# Epoch 8: starting...training completed in 11.02s...measuring accuracy...9469 / 10000 in 0.45s
# Epoch 9: starting...training completed in 10.9s...measuring accuracy...9419 / 10000 in 0.47s
# Epoch 10: starting...training completed in 11.03s...measuring accuracy...9478 / 10000 in 0.47s
# Epoch 11: starting...training completed in 10.81s...measuring accuracy...9467 / 10000 in 0.45s
# Epoch 12: starting...training completed in 10.7s...measuring accuracy...9488 / 10000 in 0.46s
# Epoch 13: starting...training completed in 10.79s...measuring accuracy...9463 / 10000 in 0.47s
# Epoch 14: starting...training completed in 10.82s...measuring accuracy...9472 / 10000 in 0.45s
# Epoch 15: starting...training completed in 10.8s...measuring accuracy...9499 / 10000 in 0.44s
# Epoch 16: starting...training completed in 11.03s...measuring accuracy...9480 / 10000 in 0.55s
# Epoch 17: starting...training completed in 10.79s...measuring accuracy...9472 / 10000 in 0.51s
# Epoch 18: starting...training completed in 10.77s...measuring accuracy...9467 / 10000 in 0.47s
# Epoch 19: starting...training completed in 11.08s...measuring accuracy...9510 / 10000 in 0.44s
# Epoch 20: starting...training completed in 10.75s...measuring accuracy...9509 / 10000 in 0.52s
# Epoch 21: starting...training completed in 11.24s...measuring accuracy...9530 / 10000 in 0.5s
# Epoch 22: starting...training completed in 11.0s...measuring accuracy...9516 / 10000 in 0.45s
# Epoch 23: starting...training completed in 10.85s...measuring accuracy...9465 / 10000 in 0.53s
# Epoch 24: starting...training completed in 10.76s...measuring accuracy...9556 / 10000 in 0.46s
# Epoch 25: starting...training completed in 10.72s...measuring accuracy...9500 / 10000 in 0.46s
# Epoch 26: starting...training completed in 10.87s...measuring accuracy...9510 / 10000 in 0.46s
# Epoch 27: starting...training completed in 10.92s...measuring accuracy...9547 / 10000 in 0.51s
# Epoch 28: starting...training completed in 10.9s...measuring accuracy...9536 / 10000 in 0.49s
# Epoch 29: starting...training completed in 10.82s...measuring accuracy...9506 / 10000 in 0.48s
# 340.3165373802185
# 0.009601178676192191
# 7921
# [784, 100, 100, 10]
# Epoch 0: starting...training completed in 25.79s...measuring accuracy...8726 / 10000 in 0.68s
# Epoch 1: starting...training completed in 25.56s...measuring accuracy...9279 / 10000 in 0.63s
# Epoch 2: starting...training completed in 25.51s...measuring accuracy...9373 / 10000 in 0.64s
# Epoch 3: starting...training completed in 25.4s...measuring accuracy...9423 / 10000 in 0.63s
# Epoch 4: starting...training completed in 25.52s...measuring accuracy...9461 / 10000 in 0.59s
# Epoch 5: starting...training completed in 25.55s...measuring accuracy...9445 / 10000 in 0.62s
# Epoch 6: starting...training completed in 25.74s...measuring accuracy...9503 / 10000 in 0.7s
# Epoch 7: starting...training completed in 25.71s...measuring accuracy...9537 / 10000 in 0.61s
# Epoch 8: starting...training completed in 25.62s...measuring accuracy...9559 / 10000 in 0.61s
# Epoch 9: starting...training completed in 25.45s...measuring accuracy...9584 / 10000 in 0.63s
# Epoch 10: starting...training completed in 25.59s...measuring accuracy...9600 / 10000 in 0.62s
# Epoch 11: starting...training completed in 25.56s...measuring accuracy...9595 / 10000 in 0.66s
# Epoch 12: starting...training completed in 25.75s...measuring accuracy...9543 / 10000 in 0.62s
# Epoch 13: starting...training completed in 25.72s...measuring accuracy...9617 / 10000 in 0.64s
# Epoch 14: starting...training completed in 25.61s...measuring accuracy...9594 / 10000 in 0.61s
# Epoch 15: starting...training completed in 25.63s...measuring accuracy...9611 / 10000 in 0.61s
# Epoch 16: starting...training completed in 25.58s...measuring accuracy...9635 / 10000 in 0.62s
# Epoch 17: starting...training completed in 25.74s...measuring accuracy...9610 / 10000 in 0.65s
# Epoch 18: starting...training completed in 25.69s...measuring accuracy...9632 / 10000 in 0.67s
# Epoch 19: starting...training completed in 25.81s...measuring accuracy...9618 / 10000 in 0.6s
# Epoch 20: starting...training completed in 25.76s...measuring accuracy...9652 / 10000 in 0.61s
# Epoch 21: starting...training completed in 25.61s...measuring accuracy...9634 / 10000 in 0.63s
# Epoch 22: starting...training completed in 25.76s...measuring accuracy...9638 / 10000 in 0.69s
# Epoch 23: starting...training completed in 25.72s...measuring accuracy...9643 / 10000 in 0.66s
# Epoch 24: starting...training completed in 25.85s...measuring accuracy...9649 / 10000 in 0.63s
# Epoch 25: starting...training completed in 25.9s...measuring accuracy...9611 / 10000 in 0.67s
# Epoch 26: starting...training completed in 25.83s...measuring accuracy...9623 / 10000 in 0.6s
# Epoch 27: starting...training completed in 25.59s...measuring accuracy...9650 / 10000 in 0.6s
# Epoch 28: starting...training completed in 26.05s...measuring accuracy...9654 / 10000 in 0.62s
# Epoch 29: starting...training completed in 25.59s...measuring accuracy...9633 / 10000 in 0.67s
# 789.2652411460876
# 0.0015741631714550608
# 2063

# %%
print("configs: ", configs)
print("TrainingTimes: ", training_times)
print("accuracies: ", accuracies)
# Out:
# configs:  [[784, 15, 10], [784, 30, 10], [784, 100, 10], [784, 15, 15, 10], [784, 30, 30, 10], [784, 100, 100, 10]]
# TrainingTimes:  [193.49233436584473, 261.9679706096649, 628.3819026947021, 259.3000485897064, 340.3165373802185, 789.2652411460876]
# accuracies:  [9280, 9505, 8535, 9326, 9506, 9633]

# %%
  from network2 import Network
  from network2 import QuadraticCost
  import mnist_loader
  import time
  import matplotlib.pyplot as plt

  training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
  configs = []
  for epochs in [15, 30, 45, 100]:
    for batchsize in [5, 10, 20, 100]:
      for learningrate in [0.1, 0.5, 1.0, 3.0, 5.0]:
        configs.append([epochs, batchsize, learningrate])

  # only train on small slice (start with 100 ... but then once you have your graphs working ... bump it up to 1000 and re-run)
  training_data = training_data[0:1000]
  test_data = test_data[0:1000]

  training_times = []
  accuracies = []  
  # note that this will be a GIANT list of training times for each config plus the two cost functions. [time1, time2, time3, time4] ... 
  #  time1 and time2 are both associated with the single hidden layer network and differ in the cost function (time1 - crossentropy, time2-quadratic)
  #  time3 and time4 are both associated with the dual hidden layer network and differ in the cost function (time3 - crossentropy, time4-quadratic)
  # NOTE: once you are happy with the results ... remove the 0:1000 and use the complete training data
  for config in configs:
    print(config, "single hidden layer plus cross-entropy")
    start = time.time()
    net1 = Network([784,15,10]) # cross-entropy cost
    accuracies.append(net1.SGD(training_data[0:10], config[0], config[1], config[2], evaluation_data=test_data[0:10], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:1000], net1)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()

    print(config, "single hidden layer plus quadratic")
    start = time.time()
    net1 = Network([784, 15, 10],cost=QuadraticCost) # quadratic cost
    accuracies.append(net1.SGD(training_data[0:1000], config[0], config[1], config[2], evaluation_data=test_data[0:10], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:1000], net1)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()

    # repeat for the two layer network
    print(config, "dual hidden layers plus cross-entropy")
    start = time.time()
    net2 = Network([784,30,15,10])
    accuracies.append(net2.SGD(training_data[0:1000], config[0], config[1], config[2], evaluation_data=test_data[0:1000], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:1000], net2)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()

    print(config, "dual hidden layers plus quadratic")
    start = time.time()
    net2 = Network([784,30,15, 10],cost=QuadraticCost)
    accuracies.append(net2.SGD(training_data[0:1000], config[0], config[1], config[2], evaluation_data=test_data[0:1000], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:1000], net2)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()
# Out:
# [15, 5, 0.1] single hidden layer plus cross-entropy
# 0.022435426712036133
# 0.17206798090635783
# 997
# [15, 5, 0.1] single hidden layer plus quadratic
# 1.9969427585601807
# 0.14238780121281566
# 603
# [15, 5, 0.1] dual hidden layers plus cross-entropy
# 3.8309006690979004
# 0.03129709899453477
# 844
# [15, 5, 0.1] dual hidden layers plus quadratic
# 3.991637706756592
# 0.13636393338588287
# 936
# [15, 5, 0.5] single hidden layer plus cross-entropy
# 0.023340463638305664
# 0.13279559841546779
# 446
# [15, 5, 0.5] single hidden layer plus quadratic
# 1.9912805557250977
# 0.07034762062108371
# 844
# [15, 5, 0.5] dual hidden layers plus cross-entropy
# 3.8657357692718506
# 0.03096112550395953
# 264
# [15, 5, 0.5] dual hidden layers plus quadratic
# 3.993314504623413
# 0.06783486803967502
# 795
# [15, 5, 1.0] single hidden layer plus cross-entropy
# 0.02827620506286621
# 0.10147884500086471
# 98
# [15, 5, 1.0] single hidden layer plus quadratic
# 1.9952805042266846
# 0.04753660138941072
# 684
# [15, 5, 1.0] dual hidden layers plus cross-entropy
# 3.877232551574707
# 0.021495972883793974
# 659
# [15, 5, 1.0] dual hidden layers plus quadratic
# 4.15383768081665
# 0.03580403518143294
# 844
# [15, 5, 3.0] single hidden layer plus cross-entropy
# 0.03124713897705078
# 0.09298607871426237
# 392
# [15, 5, 3.0] single hidden layer plus quadratic
# 1.9086668491363525
# 0.03341050837034532
# 230
# [15, 5, 3.0] dual hidden layers plus cross-entropy
# 3.780637502670288
# 0.09961648862015986
# 933
# [15, 5, 3.0] dual hidden layers plus quadratic
# 4.146285533905029
# 0.05976150687799847
# 654
# [15, 5, 5.0] single hidden layer plus cross-entropy
# 0.02690744400024414
# 0.2873819559963833
# 210
# [15, 5, 5.0] single hidden layer plus quadratic
# 1.9339954853057861
# 0.02716498417867469
# 158
# [15, 5, 5.0] dual hidden layers plus cross-entropy
# 3.8041534423828125
# 0.16700958017294984
# 588
# [15, 5, 5.0] dual hidden layers plus quadratic
# 4.042014837265015
# 0.047750948776694446
# 844
# [15, 10, 0.1] single hidden layer plus cross-entropy
# 0.029769420623779297
# 0.24215957726457454
# 495
# [15, 10, 0.1] single hidden layer plus quadratic
# 1.8374836444854736
# 0.13900302312419557
# 340
# [15, 10, 0.1] dual hidden layers plus cross-entropy
# 3.801656484603882
# 0.05448448958964499
# 881
# [15, 10, 0.1] dual hidden layers plus quadratic
# 3.972808837890625
# 0.11359066853964495
# 894
# [15, 10, 0.5] single hidden layer plus cross-entropy
# 0.030937910079956055
# 0.140222757746955
# 766
# [15, 10, 0.5] single hidden layer plus quadratic
# 1.8254132270812988
# 0.0747094392498028
# 998
# [15, 10, 0.5] dual hidden layers plus cross-entropy
# 3.6760551929473877
# 0.07444934813179428
# 324
# [15, 10, 0.5] dual hidden layers plus quadratic
# 3.899014949798584
# 0.12784335360222587
# 596
# [15, 10, 1.0] single hidden layer plus cross-entropy
# 0.0260622501373291
# 0.12562922033115562
# 462
# [15, 10, 1.0] single hidden layer plus quadratic
# 2.0941617488861084
# 0.07727879550737084
# 119
# [15, 10, 1.0] dual hidden layers plus cross-entropy
# 3.627882480621338
# 0.01934179007989001
# 261
# [15, 10, 1.0] dual hidden layers plus quadratic
# 3.884556770324707
# 0.11435555177018462
# 542
# [15, 10, 3.0] single hidden layer plus cross-entropy
# 0.02717113494873047
# 0.11639326055156471
# 72
# [15, 10, 3.0] single hidden layer plus quadratic
# 2.083998918533325
# 0.05595210198552541
# 340
# [15, 10, 3.0] dual hidden layers plus cross-entropy
# 3.6933977603912354
# 0.13518497755255224
# 508
# [15, 10, 3.0] dual hidden layers plus quadratic
# 3.872558116912842
# 0.03439396991965301
# 795
# [15, 10, 5.0] single hidden layer plus cross-entropy
# 0.02939581871032715
# 0.09808054107874259
# 871
# [15, 10, 5.0] single hidden layer plus quadratic
# 1.8885550498962402
# 0.058359621905877956
# 244
# [15, 10, 5.0] dual hidden layers plus cross-entropy
# 3.6000137329101562
# 0.06452381202892563
# 428
# [15, 10, 5.0] dual hidden layers plus quadratic
# 3.907339096069336
# 0.0652270951297399
# 726
# [15, 20, 0.1] single hidden layer plus cross-entropy
# 0.03895092010498047
# 0.25904219685302704
# 120
# [15, 20, 0.1] single hidden layer plus quadratic
# 1.8832194805145264
# 0.12704452089831733
# 181
# [15, 20, 0.1] dual hidden layers plus cross-entropy
# 3.5815773010253906
# 0.1104012292221526
# 236
# [15, 20, 0.1] dual hidden layers plus quadratic
# 3.9163711071014404
# 0.11510147440088259
# 200
# [15, 20, 0.5] single hidden layer plus cross-entropy
# 0.040023088455200195
# 0.14468930940671954
# 710
# [15, 20, 0.5] single hidden layer plus quadratic
# 1.868056058883667
# 0.14503890893768692
# 596
# [15, 20, 0.5] dual hidden layers plus cross-entropy
# 3.564068078994751
# 0.02190597485905288
# 552
# [15, 20, 0.5] dual hidden layers plus quadratic
# 3.8250179290771484
# 0.12221054539212066
# 22
# [15, 20, 1.0] single hidden layer plus cross-entropy
# 0.039691925048828125
# 0.1300707242600925
# 223
# [15, 20, 1.0] single hidden layer plus quadratic
# 1.8918800354003906
# 0.15396526643272038
# 456
# [15, 20, 1.0] dual hidden layers plus cross-entropy
# 3.5303354263305664
# 0.056654794489994165
# 502
# [15, 20, 1.0] dual hidden layers plus quadratic
# 3.9110772609710693
# 0.11122231814843182
# 303
# [15, 20, 3.0] single hidden layer plus cross-entropy
# 0.028143882751464844
# 0.08845267557206415
# 732
# [15, 20, 3.0] single hidden layer plus quadratic
# 1.8977406024932861
# 0.09880128322878567
# 610
# [15, 20, 3.0] dual hidden layers plus cross-entropy
# 3.5480895042419434
# 0.021273222483661952
# 950
# [15, 20, 3.0] dual hidden layers plus quadratic
# 3.855184316635132
# 0.15192947899459452
# 528
# [15, 20, 5.0] single hidden layer plus cross-entropy
# 0.04292774200439453
# 0.14417199922485952
# 633
# [15, 20, 5.0] single hidden layer plus quadratic
# 1.9245386123657227
# 0.07352411951002819
# 247
# [15, 20, 5.0] dual hidden layers plus cross-entropy
# 3.5661978721618652
# 0.04620421659439886
# 952
# [15, 20, 5.0] dual hidden layers plus quadratic
# 3.811448812484741
# 0.03883616796220907
# 403
# [15, 100, 0.1] single hidden layer plus cross-entropy
# 0.030444860458374023
# 0.24463250224920863
# 871
# [15, 100, 0.1] single hidden layer plus quadratic
# 1.8272960186004639
# 0.11671287486942378
# 95
# [15, 100, 0.1] dual hidden layers plus cross-entropy
# 3.907200813293457
# 0.11505074840318605
# 462
# [15, 100, 0.1] dual hidden layers plus quadratic
# 3.7555856704711914
# 0.1323233183856973
# 25
# [15, 100, 0.5] single hidden layer plus cross-entropy
# 0.031853675842285156
# 0.15396322812058008
# 222
# [15, 100, 0.5] single hidden layer plus quadratic
# 1.8562960624694824
# 0.12643902296320186
# 645
# [15, 100, 0.5] dual hidden layers plus cross-entropy
# 3.520637035369873
# 0.094844908722782
# 603
# [15, 100, 0.5] dual hidden layers plus quadratic
# 3.7605974674224854
# 0.11402949585411379
# 25
# [15, 100, 1.0] single hidden layer plus cross-entropy
# 0.02655935287475586
# 0.11815874384765714
# 462
# [15, 100, 1.0] single hidden layer plus quadratic
# 1.846195936203003
# 0.1347575065255856
# 195
# [15, 100, 1.0] dual hidden layers plus cross-entropy
# 3.4879860877990723
# 0.06538682744287463
# 177
# [15, 100, 1.0] dual hidden layers plus quadratic
# 3.9115183353424072
# 0.11371149171523341
# 25
# [15, 100, 3.0] single hidden layer plus cross-entropy
# 0.039621829986572266
# 0.10966193486329673
# 424
# [15, 100, 3.0] single hidden layer plus quadratic
# 1.786879062652588
# 0.136631928406387
# 795
# [15, 100, 3.0] dual hidden layers plus cross-entropy
# 3.4708609580993652
# 0.06208212771545931
# 741
# [15, 100, 3.0] dual hidden layers plus quadratic
# 3.726595640182495
# 0.13521019623689823
# 806
# [15, 100, 5.0] single hidden layer plus cross-entropy
# 0.03245234489440918
# 0.13388033926566598
# 224
# [15, 100, 5.0] single hidden layer plus quadratic
# 1.8054523468017578
# 0.1393524967301569
# 654
# [15, 100, 5.0] dual hidden layers plus cross-entropy
# 3.6283199787139893
# 0.07460547283349352
# 747
# [15, 100, 5.0] dual hidden layers plus quadratic
# 3.7765724658966064
# 0.13065178264811306
# 387
# [30, 5, 0.1] single hidden layer plus cross-entropy
# 0.06387019157409668
# 0.15124737326969592
# 495
# [30, 5, 0.1] single hidden layer plus quadratic
# 4.1012983322143555
# 0.147582814622908
# 661
# [30, 5, 0.1] dual hidden layers plus cross-entropy
# 7.587627649307251
# 0.028652385771905996
# 59
# [30, 5, 0.1] dual hidden layers plus quadratic
# 8.345072031021118
# 0.12325163571835299
# 779
# [30, 5, 0.5] single hidden layer plus cross-entropy
# 0.05608868598937988
# 0.09571306102720739
# 233
# [30, 5, 0.5] single hidden layer plus quadratic
# 3.9465315341949463
# 0.09515544183078982
# 290
# [30, 5, 0.5] dual hidden layers plus cross-entropy
# 7.602403402328491
# 0.023825111991625327
# 938
# [30, 5, 0.5] dual hidden layers plus quadratic
# 8.039230585098267
# 0.09429451549377388
# 195
# [30, 5, 1.0] single hidden layer plus cross-entropy
# 0.057758331298828125
# 0.051523977335286006
# 986
# [30, 5, 1.0] single hidden layer plus quadratic
# 3.882011651992798
# 0.03425389322857777
# 514
# [30, 5, 1.0] dual hidden layers plus cross-entropy
# 7.527139186859131
# 0.012461263899095371
# 960
# [30, 5, 1.0] dual hidden layers plus quadratic
# 8.209505796432495
# 0.04220579289017023
# 244
# [30, 5, 3.0] single hidden layer plus cross-entropy
# 0.05447864532470703
# 0.07148041626241115
# 333
# [30, 5, 3.0] single hidden layer plus quadratic
# 3.8887431621551514
# 0.04597855157626584
# 610
# [30, 5, 3.0] dual hidden layers plus cross-entropy
# 7.797577857971191
# 0.12791125540973045
# 939
# [30, 5, 3.0] dual hidden layers plus quadratic
# 8.03948974609375
# 0.07348569796404839
# 684
# [30, 5, 5.0] single hidden layer plus cross-entropy
# 0.05337786674499512
# 0.05369773071494855
# 564
# [30, 5, 5.0] single hidden layer plus quadratic
# 4.08102011680603
# 0.07413837789076551
# 435
# [30, 5, 5.0] dual hidden layers plus cross-entropy
# 7.544064283370972
# 0.30529964279660926
# 917
# [30, 5, 5.0] dual hidden layers plus quadratic
# 8.036701917648315
# 0.02700151290362456
# 18
# [30, 10, 0.1] single hidden layer plus cross-entropy
# 0.05787014961242676
# 0.23178900284755527
# 25
# [30, 10, 0.1] single hidden layer plus quadratic
# 3.746807336807251
# 0.1279264919844098
# 761
# [30, 10, 0.1] dual hidden layers plus cross-entropy
# 7.348011016845703
# 0.04279889172170834
# 844
# [30, 10, 0.1] dual hidden layers plus quadratic
# 7.76810622215271
# 0.11421950219020223
# 801
# [30, 10, 0.5] single hidden layer plus cross-entropy
# 0.06134438514709473
# 0.11827660522992964
# 448
# [30, 10, 0.5] single hidden layer plus quadratic
# 3.7154629230499268
# 0.08861518110904085
# 514
# [30, 10, 0.5] dual hidden layers plus cross-entropy
# 7.310787200927734
# 0.02176550301545328
# 479
# [30, 10, 0.5] dual hidden layers plus quadratic
# 7.809025287628174
# 0.09417817504873206
# 456
# [30, 10, 1.0] single hidden layer plus cross-entropy
# 0.052098989486694336
# 0.09501347479503303
# 886
# [30, 10, 1.0] single hidden layer plus quadratic
# 3.7832725048065186
# 0.040616650207624366
# 403
# [30, 10, 1.0] dual hidden layers plus cross-entropy
# 7.324813365936279
# 0.011602883768493022
# 433
# [30, 10, 1.0] dual hidden layers plus quadratic
# 7.830715656280518
# 0.1514045034361639
# 950
# [30, 10, 3.0] single hidden layer plus cross-entropy
# 0.09795522689819336
# 0.045580165842164434
# 53
# [30, 10, 3.0] single hidden layer plus quadratic
# 3.728884696960449
# 0.027627770540030207
# 230
# [30, 10, 3.0] dual hidden layers plus cross-entropy
# 7.240176439285278
# 0.11186208621158732
# 242
# [30, 10, 3.0] dual hidden layers plus quadratic
# 8.045207738876343
# 0.04879734194329029
# 570
# [30, 10, 5.0] single hidden layer plus cross-entropy
# 0.06182527542114258
# 0.06979482527952843
# 566
# [30, 10, 5.0] single hidden layer plus quadratic
# 3.703918695449829
# 0.030857438785672747
# 619
# [30, 10, 5.0] dual hidden layers plus cross-entropy
# 7.23201322555542
# 0.14704808957129908
# 351
# [30, 10, 5.0] dual hidden layers plus quadratic
# 7.876353740692139
# 0.0606348324862148
# 527
# [30, 20, 0.1] single hidden layer plus cross-entropy
# 0.05697035789489746
# 0.18080745697072767
# 311
# [30, 20, 0.1] single hidden layer plus quadratic
# 3.660395383834839
# 0.11722502956214961
# 260
# [30, 20, 0.1] dual hidden layers plus cross-entropy
# 7.128636360168457
# 0.0890798774660032
# 242
# [30, 20, 0.1] dual hidden layers plus quadratic
# 7.765187740325928
# 0.11483951666211253
# 580
# [30, 20, 0.5] single hidden layer plus cross-entropy
# 0.06666064262390137
# 0.11943230026265249
# 864
# [30, 20, 0.5] single hidden layer plus quadratic
# 3.6076581478118896
# 0.12839272785337963
# 514
# [30, 20, 0.5] dual hidden layers plus cross-entropy
# 7.28432035446167
# 0.05793556723368471
# 495
# [30, 20, 0.5] dual hidden layers plus quadratic
# 7.710471153259277
# 0.13157630452033095
# 779
# [30, 20, 1.0] single hidden layer plus cross-entropy
# 0.06278038024902344
# 0.06385588301655215
# 986
# [30, 20, 1.0] single hidden layer plus quadratic
# 3.628300428390503
# 0.06578457116463556
# 619
# [30, 20, 1.0] dual hidden layers plus cross-entropy
# 7.201784610748291
# 0.03501418824829965
# 844
# [30, 20, 1.0] dual hidden layers plus quadratic
# 7.857511520385742
# 0.111466589511311
# 844
# [30, 20, 3.0] single hidden layer plus cross-entropy
# 0.06724834442138672
# 0.08203695434998796
# 861
# [30, 20, 3.0] single hidden layer plus quadratic
# 3.679330348968506
# 0.0509439468649204
# 230
# [30, 20, 3.0] dual hidden layers plus cross-entropy
# 7.165895462036133
# 0.02064746038992453
# 528
# [30, 20, 3.0] dual hidden layers plus quadratic
# 7.8276262283325195
# 0.04980949885869125
# 844
# [30, 20, 5.0] single hidden layer plus cross-entropy
# 0.06655669212341309
# 0.10367619800880185
# 410
# [30, 20, 5.0] single hidden layer plus quadratic
# 3.7396578788757324
# 0.03723038939316498
# 876
# [30, 20, 5.0] dual hidden layers plus cross-entropy
# 7.130697250366211
# 0.1217551069507427
# 829
# [30, 20, 5.0] dual hidden layers plus quadratic
# 7.722058296203613
# 0.02229188595639465
# 77
# [30, 100, 0.1] single hidden layer plus cross-entropy
# 0.06576967239379883
# 0.1797428615274804
# 495
# [30, 100, 0.1] single hidden layer plus quadratic
# 3.6046504974365234
# 0.11159633736938426
# 250
# [30, 100, 0.1] dual hidden layers plus cross-entropy
# 7.102221250534058
# 0.11237278494284776
# 266
# [30, 100, 0.1] dual hidden layers plus quadratic
# 7.565279245376587
# 0.11534128701784441
# 200
# [30, 100, 0.5] single hidden layer plus cross-entropy
# 0.055025577545166016
# 0.11573678932430298
# 661
# [30, 100, 0.5] single hidden layer plus quadratic
# 3.779292106628418
# 0.13345302407416726
# 936
# [30, 100, 0.5] dual hidden layers plus cross-entropy
# 6.967087984085083
# 0.06370787035547552
# 151
# [30, 100, 0.5] dual hidden layers plus quadratic
# 7.665389776229858
# 0.11069484555576083
# 736
# [30, 100, 1.0] single hidden layer plus cross-entropy
# 0.05818295478820801
# 0.09262861485297214
# 885
# [30, 100, 1.0] single hidden layer plus quadratic
# 3.636615514755249
# 0.1283080936085887
# 693
# [30, 100, 1.0] dual hidden layers plus cross-entropy
# 7.163690567016602
# 0.035873089448691074
# 104
# [30, 100, 1.0] dual hidden layers plus quadratic
# 7.592197895050049
# 0.11639616864731638
# 406
# [30, 100, 3.0] single hidden layer plus cross-entropy
# 0.0707852840423584
# 0.07177621760975082
# 538
# [30, 100, 3.0] single hidden layer plus quadratic
# 3.578648090362549
# 0.14219414067104744
# 998
# [30, 100, 3.0] dual hidden layers plus cross-entropy
# 7.036900758743286
# 0.018258609134545183
# 795
# [30, 100, 3.0] dual hidden layers plus quadratic
# 7.722776889801025
# 0.13671939066691782
# 195
# [30, 100, 5.0] single hidden layer plus cross-entropy
# 0.10145401954650879
# 0.12590257646718153
# 181
# [30, 100, 5.0] single hidden layer plus quadratic
# 3.5453076362609863
# 0.08425708338949359
# 844
# [30, 100, 5.0] dual hidden layers plus cross-entropy
# 7.059773206710815
# 0.06399704618220604
# 97
# [30, 100, 5.0] dual hidden layers plus quadratic
# 7.539778232574463
# 0.0954501444099645
# 844
# [45, 5, 0.1] single hidden layer plus cross-entropy
# 0.07863736152648926
# 0.15637151545291386
# 941
# [45, 5, 0.1] single hidden layer plus quadratic
# 5.770143508911133
# 0.1087438300029174
# 456
# [45, 5, 0.1] dual hidden layers plus cross-entropy
# 11.39290189743042
# 0.017387230929542134
# 456
# [45, 5, 0.1] dual hidden layers plus quadratic
# 12.144336938858032
# 0.0985670852006113
# 236
# [45, 5, 0.5] single hidden layer plus cross-entropy
# 0.07491111755371094
# 0.04856457064844049
# 79
# [45, 5, 0.5] single hidden layer plus quadratic
# 5.767864465713501
# 0.02330838580915825
# 514
# [45, 5, 0.5] dual hidden layers plus cross-entropy
# 11.410520315170288
# 0.01538909151678025
# 791
# [45, 5, 0.5] dual hidden layers plus quadratic
# 12.236598253250122
# 0.0728409972144164
# 456
# [45, 5, 1.0] single hidden layer plus cross-entropy
# 0.09414434432983398
# 0.04274224246658056
# 443
# [45, 5, 1.0] single hidden layer plus quadratic
# 5.954107999801636
# 0.035987946364947634
# 944
# [45, 5, 1.0] dual hidden layers plus cross-entropy
# 11.472343683242798
# 0.027504772561480727
# 104
# [45, 5, 1.0] dual hidden layers plus quadratic
# 12.206163883209229
# 0.04789856397903164
# 479
# [45, 5, 3.0] single hidden layer plus cross-entropy
# 0.08844780921936035
# 0.04196632879541363
# 54
# [45, 5, 3.0] single hidden layer plus quadratic
# 5.796815395355225
# 0.021568524292115233
# 460
# [45, 5, 3.0] dual hidden layers plus cross-entropy
# /content/nn3/src/network2.py:326: RuntimeWarning: overflow encountered in exp
#   return 1.0/(1.0+np.exp(-z))
# 11.462720155715942
# 0.04106632614190437
# 658
# [45, 5, 3.0] dual hidden layers plus quadratic
# 12.12001633644104
# 0.03400282312147827
# 479
# [45, 5, 5.0] single hidden layer plus cross-entropy
# 0.09167885780334473
# 0.016213094995547062
# 542
# [45, 5, 5.0] single hidden layer plus quadratic
# 5.714039325714111
# 0.01658539912160541
# 612
# [45, 5, 5.0] dual hidden layers plus cross-entropy
# 11.452159881591797
# 0.3952591007920316
# 192
# [45, 5, 5.0] dual hidden layers plus quadratic
# 12.226123809814453
# 0.0099920822268209
# 97
# [45, 10, 0.1] single hidden layer plus cross-entropy
# 0.11787915229797363
# 0.16498043467409707
# 311
# [45, 10, 0.1] single hidden layer plus quadratic
# 5.652764558792114
# 0.13463366697923637
# 795
# [45, 10, 0.1] dual hidden layers plus cross-entropy
# 11.127158641815186
# 0.06121011224054697
# 230
# [45, 10, 0.1] dual hidden layers plus quadratic
# 11.830534934997559
# 0.11963189706913573
# 453
# [45, 10, 0.5] single hidden layer plus cross-entropy
# 0.08472084999084473
# 0.09626404692105989
# 786
# [45, 10, 0.5] single hidden layer plus quadratic
# 5.571969985961914
# 0.08799338037568616
# 684
# [45, 10, 0.5] dual hidden layers plus cross-entropy
# 11.129698753356934
# 0.018833940597167486
# 542
# [45, 10, 0.5] dual hidden layers plus quadratic
# 11.640570402145386
# 0.11261907637217174
# 283
# [45, 10, 1.0] single hidden layer plus cross-entropy
# 0.08709239959716797
# 0.05839993256849275
# 632
# [45, 10, 1.0] single hidden layer plus quadratic
# 5.52234959602356
# 0.018747529352032964
# 403
# [45, 10, 1.0] dual hidden layers plus cross-entropy
# 11.099313974380493
# 0.00985064124009082
# 684
# [45, 10, 1.0] dual hidden layers plus quadratic
# 11.8968346118927
# 0.03694214847550227
# 479
# [45, 10, 3.0] single hidden layer plus cross-entropy
# 0.09012365341186523
# 0.042129393191816106
# 786
# [45, 10, 3.0] single hidden layer plus quadratic
# 5.648619651794434
# 0.012824314986674874
# 844
# [45, 10, 3.0] dual hidden layers plus cross-entropy
# 11.109990358352661
# 0.046509087992586774
# 728
# [45, 10, 3.0] dual hidden layers plus quadratic
# 11.665604591369629
# 0.04317198751040662
# 77
# [45, 10, 5.0] single hidden layer plus cross-entropy
# 0.09448051452636719
# 0.05075677812220202
# 195
# [45, 10, 5.0] single hidden layer plus quadratic
# 5.485765218734741
# 0.02574027751234433
# 479
# [45, 10, 5.0] dual hidden layers plus cross-entropy
# 10.925021409988403
# 0.06021757703324394
# 433
# [45, 10, 5.0] dual hidden layers plus quadratic
# 11.846750497817993
# 0.035037777165600414
# 514
# [45, 20, 0.1] single hidden layer plus cross-entropy
# 0.08401179313659668
# 0.1726178904520179
# 215
# [45, 20, 0.1] single hidden layer plus quadratic
# 5.433762550354004
# 0.1494041102498723
# 684
# [45, 20, 0.1] dual hidden layers plus cross-entropy
# 10.672817468643188
# 0.05045666465966021
# 119
# [45, 20, 0.1] dual hidden layers plus quadratic
# 11.721048355102539
# 0.11762680144238263
# 50
# [45, 20, 0.5] single hidden layer plus cross-entropy
# 0.08482933044433594
# 0.11341478177879813
# 462
# [45, 20, 0.5] single hidden layer plus quadratic
# 5.460446119308472
# 0.08594380122144564
# 514
# [45, 20, 0.5] dual hidden layers plus cross-entropy
# 10.751646518707275
# 0.005307416802313986
# 844
# [45, 20, 0.5] dual hidden layers plus quadratic
# 11.603569984436035
# 0.12863566279224808
# 596
# [45, 20, 1.0] single hidden layer plus cross-entropy
# 0.07959842681884766
# 0.061118727173572036
# 233
# [45, 20, 1.0] single hidden layer plus quadratic
# 5.470776796340942
# 0.051110827246000586
# 514
# [45, 20, 1.0] dual hidden layers plus cross-entropy
# 10.789946556091309
# 0.02654765438537225
# 479
# [45, 20, 1.0] dual hidden layers plus quadratic
# 11.675268411636353
# 0.1001879854550483
# 119
# [45, 20, 3.0] single hidden layer plus cross-entropy
# 0.07954859733581543
# 0.050482081955616515
# 324
# [45, 20, 3.0] single hidden layer plus quadratic
# 5.502635955810547
# 0.023850982281670353
# 998
# [45, 20, 3.0] dual hidden layers plus cross-entropy
# 10.881900310516357
# 0.02193779714196816
# 781
# [45, 20, 3.0] dual hidden layers plus quadratic
# 11.673075199127197
# 0.0628373827924237
# 119
# [45, 20, 5.0] single hidden layer plus cross-entropy
# 0.09111571311950684
# 0.053439798043301484
# 602
# [45, 20, 5.0] single hidden layer plus quadratic
# 5.497762680053711
# 0.029187729805356256
# 341
# [45, 20, 5.0] dual hidden layers plus cross-entropy
# 10.92006230354309
# 0.0936969212791736
# 787
# [45, 20, 5.0] dual hidden layers plus quadratic
# 11.5006685256958
# 0.09552708917775642
# 479
# [45, 100, 0.1] single hidden layer plus cross-entropy
# 0.11724400520324707
# 0.18740457940985536
# 446
# [45, 100, 0.1] single hidden layer plus quadratic
# 5.341782569885254
# 0.11872565466687733
# 645
# [45, 100, 0.1] dual hidden layers plus cross-entropy
# 10.656222581863403
# 0.10570128578915003
# 710
# [45, 100, 0.1] dual hidden layers plus quadratic
# 11.602998733520508
# 0.10960901185206098
# 222
# [45, 100, 0.5] single hidden layer plus cross-entropy
# 0.09600973129272461
# 0.10051652282103135
# 852
# [45, 100, 0.5] single hidden layer plus quadratic
# 5.415328741073608
# 0.14646726805230856
# 507
# [45, 100, 0.5] dual hidden layers plus cross-entropy
# 10.57397174835205
# 0.050613184497295835
# 795
# [45, 100, 0.5] dual hidden layers plus quadratic
# 11.39851713180542
# 0.11950656505133553
# 495
# [45, 100, 1.0] single hidden layer plus cross-entropy
# 0.09544920921325684
# 0.07715020041546401
# 462
# [45, 100, 1.0] single hidden layer plus quadratic
# 5.374593496322632
# 0.1232361990037883
# 998
# [45, 100, 1.0] dual hidden layers plus cross-entropy
# 10.470372915267944
# 0.06827915614141783
# 151
# [45, 100, 1.0] dual hidden layers plus quadratic
# 11.370264530181885
# 0.13537790252920434
# 569
# [45, 100, 3.0] single hidden layer plus cross-entropy
# 0.1240847110748291
# 0.06491704265931011
# 324
# [45, 100, 3.0] single hidden layer plus quadratic
# 5.507252216339111
# 0.12103114533256315
# 878
# [45, 100, 3.0] dual hidden layers plus cross-entropy
# 10.767387390136719
# 0.03937698192940592
# 247
# [45, 100, 3.0] dual hidden layers plus quadratic
# 11.426764965057373
# 0.10313326340473636
# 195
# [45, 100, 5.0] single hidden layer plus cross-entropy
# 0.09827303886413574
# 0.07768267156885048
# 208
# [45, 100, 5.0] single hidden layer plus quadratic
# 5.381641149520874
# 0.11188048280674473
# 878
# [45, 100, 5.0] dual hidden layers plus cross-entropy
# 10.493120908737183
# 0.10313342853470195
# 527
# [45, 100, 5.0] dual hidden layers plus quadratic
# 11.33604907989502
# 0.04092784210184969
# 77
# [100, 5, 0.1] single hidden layer plus cross-entropy
# 0.17117595672607422
# 0.11255479479479874
# 769
# [100, 5, 0.1] single hidden layer plus quadratic
# 12.844645023345947
# 0.10529331592229672
# 514
# [100, 5, 0.1] dual hidden layers plus cross-entropy
# 25.45355725288391
# 0.01852339777756793
# 726
# [100, 5, 0.1] dual hidden layers plus quadratic
# 27.1139714717865
# 0.11551341071196504
# 151
# [100, 5, 0.5] single hidden layer plus cross-entropy
# 0.16213226318359375
# 0.03603020199543413
# 313
# [100, 5, 0.5] single hidden layer plus quadratic
# 12.729573488235474
# 0.044011063596803394
# 514
# [100, 5, 0.5] dual hidden layers plus cross-entropy
# 25.335630178451538
# 0.004212326590997069
# 403
# [100, 5, 0.5] dual hidden layers plus quadratic
# 26.869064331054688
# 0.035479046084710406
# 844
# [100, 5, 1.0] single hidden layer plus cross-entropy
# 0.1710960865020752
# 0.018885150626323868
# 260
# [100, 5, 1.0] single hidden layer plus quadratic
# 13.08158254623413
# 0.03343365026820985
# 403
# [100, 5, 1.0] dual hidden layers plus cross-entropy
# 25.35754156112671
# 0.010589393865177309
# 59
# [100, 5, 1.0] dual hidden layers plus quadratic
# 26.988897800445557
# 0.023751758201917977
# 403
# [100, 5, 3.0] single hidden layer plus cross-entropy
# 0.17177438735961914
# 0.031098876508759123
# 65
# [100, 5, 3.0] single hidden layer plus quadratic
# 12.660917043685913
# 0.007588491249891462
# 433
# [100, 5, 3.0] dual hidden layers plus cross-entropy
# 25.133684635162354
# 0.06795148186650768
# 408
# [100, 5, 3.0] dual hidden layers plus quadratic
# 27.08619499206543
# 0.02969955411879054
# 514
# [100, 5, 5.0] single hidden layer plus cross-entropy
# 0.17749929428100586
# 0.09597892083006959
# 944
# [100, 5, 5.0] single hidden layer plus quadratic
# 12.985724449157715
# 0.020324424680741665
# 59
# [100, 5, 5.0] dual hidden layers plus cross-entropy
# 25.31304955482483
# 0.6518969995835426
# 231
# [100, 5, 5.0] dual hidden layers plus quadratic
# 26.9986355304718
# 0.030838009178382086
# 511
# [100, 10, 0.1] single hidden layer plus cross-entropy
# 0.1692030429840088
# 0.14887412012876422
# 552
# [100, 10, 0.1] single hidden layer plus quadratic
# 12.480718612670898
# 0.11214636677257098
# 795
# [100, 10, 0.1] dual hidden layers plus cross-entropy
# 23.93635058403015
# 0.010912522651350403
# 844
# [100, 10, 0.1] dual hidden layers plus quadratic
# 26.282700061798096
# 0.1269822030812484
# 317
# [100, 10, 0.5] single hidden layer plus cross-entropy
# 0.17248773574829102
# 0.04372298363832331
# 339
# [100, 10, 0.5] single hidden layer plus quadratic
# 12.576853513717651
# 0.07422630584206431
# 844
# [100, 10, 0.5] dual hidden layers plus cross-entropy
# 24.473917722702026
# 0.019614385016812858
# 844
# [100, 10, 0.5] dual hidden layers plus quadratic
# 25.94171905517578
# 0.01961525881702778
# 844
# [100, 10, 1.0] single hidden layer plus cross-entropy
# 0.17470693588256836
# 0.03866335538831188
# 207
# [100, 10, 1.0] single hidden layer plus quadratic
# 12.344933271408081
# 0.028429542661868173
# 514
# [100, 10, 1.0] dual hidden layers plus cross-entropy
# 24.193944454193115
# 0.006007556372630073
# 149
# [100, 10, 1.0] dual hidden layers plus quadratic
# 26.000977516174316
# 0.015590611378100461
# 244
# [100, 10, 3.0] single hidden layer plus cross-entropy
# 0.18779706954956055
# 0.031697274333577635
# 98
# [100, 10, 3.0] single hidden layer plus quadratic
# 12.14835786819458
# 0.030026335840019455
# 844
# [100, 10, 3.0] dual hidden layers plus cross-entropy
# 24.16191267967224
# 0.03244642581010931
# 930
# [100, 10, 3.0] dual hidden layers plus quadratic
# 25.83170223236084
# 0.028182161132592448
# 551
# [100, 10, 5.0] single hidden layer plus cross-entropy
# 0.1688401699066162
# 0.028917022403432847
# 568
# [100, 10, 5.0] single hidden layer plus quadratic
# 12.525612831115723
# 0.015151322881771604
# 18
# [100, 10, 5.0] dual hidden layers plus cross-entropy
# 24.07172656059265
# 0.07956466577463142
# 421
# [100, 10, 5.0] dual hidden layers plus quadratic
# 26.19890546798706
# 0.04727827238144605
# 543
# [100, 20, 0.1] single hidden layer plus cross-entropy
# 0.19242382049560547
# 0.14821917264981369
# 222
# [100, 20, 0.1] single hidden layer plus quadratic
# 11.95125937461853
# 0.14102914225249968
# 878
# [100, 20, 0.1] dual hidden layers plus cross-entropy
# 23.559352159500122
# 0.01567936742485
# 883
# [100, 20, 0.1] dual hidden layers plus quadratic
# 25.64039659500122
# 0.11785709651331236
# 569
# [100, 20, 0.5] single hidden layer plus cross-entropy
# 0.16865181922912598
# 0.042831283254828406
# 986
# [100, 20, 0.5] single hidden layer plus quadratic
# 12.1785728931427
# 0.05333021581367583
# 341
# [100, 20, 0.5] dual hidden layers plus cross-entropy
# 23.468966007232666
# 0.0470664412445251
# 930
# [100, 20, 0.5] dual hidden layers plus quadratic
# 25.586122035980225
# 0.08590794236209878
# 844
# [100, 20, 1.0] single hidden layer plus cross-entropy
# 0.2295513153076172
# 0.03274399594833619
# 986
# [100, 20, 1.0] single hidden layer plus quadratic
# 12.126920461654663
# 0.08662569226367788
# 542
# [100, 20, 1.0] dual hidden layers plus cross-entropy
# 23.963845252990723
# 0.010298794445027891
# 230
# [100, 20, 1.0] dual hidden layers plus quadratic
# 26.12109899520874
# 0.05324483527616176
# 898
# [100, 20, 3.0] single hidden layer plus cross-entropy
# 0.18396210670471191
# 0.039658709232130294
# 233
# [100, 20, 3.0] single hidden layer plus quadratic
# 12.017805337905884
# 0.04113231801148265
# 950
# [100, 20, 3.0] dual hidden layers plus cross-entropy
# 23.77252173423767
# 0.0072007421840761705
# 433
# [100, 20, 3.0] dual hidden layers plus quadratic
# 26.07244086265564
# 0.04112944415810829
# 514
# [100, 20, 5.0] single hidden layer plus cross-entropy
# 0.17728662490844727
# 0.24839957178729682
# 746
# [100, 20, 5.0] single hidden layer plus quadratic
# 12.172888994216919
# 0.01382797609613539
# 543
# [100, 20, 5.0] dual hidden layers plus cross-entropy
# 23.990800380706787
# 0.011936162834604648
# 513
# [100, 20, 5.0] dual hidden layers plus quadratic
# 25.831648349761963
# 0.021551999750824422
# 403
# [100, 100, 0.1] single hidden layer plus cross-entropy
# 0.1685473918914795
# 0.13567216861534354
# 864
# [100, 100, 0.1] single hidden layer plus quadratic
# 11.776487350463867
# 0.11662424435445161
# 61
# [100, 100, 0.1] dual hidden layers plus cross-entropy
# 23.62767457962036
# 0.07651169062779682
# 844
# [100, 100, 0.1] dual hidden layers plus quadratic
# 24.96050453186035
# 0.11269420364090812
# 311
# [100, 100, 0.5] single hidden layer plus cross-entropy
# 0.19541025161743164
# 0.05222460698997766
# 940
# [100, 100, 0.5] single hidden layer plus quadratic
# 11.979894638061523
# 0.12779163174419325
# 930
# [100, 100, 0.5] dual hidden layers plus cross-entropy
# 23.375004768371582
# 0.06288771120011744
# 613
# [100, 100, 0.5] dual hidden layers plus quadratic
# 25.25348973274231
# 0.11807666960100156
# 66
# [100, 100, 1.0] single hidden layer plus cross-entropy
# 0.15261006355285645
# 0.04407926022872557
# 79
# [100, 100, 1.0] single hidden layer plus quadratic
# 11.862552404403687
# 0.14083252796427623
# 878
# [100, 100, 1.0] dual hidden layers plus cross-entropy
# 23.356268405914307
# 0.010599896378813539
# 247
# [100, 100, 1.0] dual hidden layers plus quadratic
# 25.3017361164093
# 0.10611836343149951
# 277
# [100, 100, 3.0] single hidden layer plus cross-entropy
# 0.18951416015625
# 0.03907486345163993
# 313
# [100, 100, 3.0] single hidden layer plus quadratic
# 12.027246952056885
# 0.0718255363106179
# 514
# [100, 100, 3.0] dual hidden layers plus cross-entropy
# 23.348337650299072
# 0.015051121680282982
# 211
# [100, 100, 3.0] dual hidden layers plus quadratic
# 25.21761918067932
# 0.13574662274750893
# 479
# [100, 100, 5.0] single hidden layer plus cross-entropy
# 0.2015361785888672
# 0.030056587446320216
# 291
# [100, 100, 5.0] single hidden layer plus quadratic
# 11.825095176696777
# 0.027090963530538234
# 844
# [100, 100, 5.0] dual hidden layers plus cross-entropy
# 23.202520847320557
# 0.03357701084589096
# 1
# [100, 100, 5.0] dual hidden layers plus quadratic
# 25.51699137687683
# 0.029120800426992326
# 456

# %%
import matplotlib.pyplot as plt

# pre-process our really janked up data ... first the training_times
training_timesSingle1 = training_times[0::4]
training_timesSingle2 = training_times[1::4]
training_timesDouble1 = training_times[2::4]
training_timesDouble2 = training_times[3::4]
training_timesSingle = []
training_timesDouble = []
for tt1, tt2 in zip(training_timesSingle1, training_timesSingle2):
    training_timesSingle.append(tt1)
    training_timesSingle.append(tt2)
for tt1, tt2 in zip(training_timesDouble1, training_timesDouble2):
    training_timesDouble.append(tt1)
    training_timesDouble.append(tt2)

# and now the accuracies...
accuraciesSingle1 = accuracies[0::4]
accuraciesSingle2 = accuracies[1::4]
accuraciesDouble1 = accuracies[2::4]
accuraciesDouble2 = accuracies[3::4]
accuraciesSingle = []
accuraciesDouble = []
for acc1, acc2 in zip(accuraciesSingle1, accuraciesSingle2):
    accuraciesSingle.append(acc1[1][-1])
    accuraciesSingle.append(acc2[1][-1])
for acc1, acc2 in zip(accuraciesDouble1, accuraciesDouble2):
    accuraciesDouble.append(acc1[1][-1])
    accuraciesDouble.append(acc2[1][-1])

# and now the labels
labelsSingle = []
labelsDouble = []
for config in configs:
    labelsSingle.append(f"{config}-cross-784-15-10")
    labelsSingle.append(f"{config}-quad-784-15-10")
    labelsDouble.append(f"{config}-cross-784-30-15-10")
    labelsDouble.append(f"{config}-quad-784-30-15-10")

fig, ax = plt.subplots(figsize=(50,10))
ax.plot(labelsSingle, accuraciesSingle)
plt.show()
fig, ax = plt.subplots(figsize=(50,10))
ax.plot(labelsDouble, training_timesDouble)
plt.show()

# %%
# extract the "results" (training times and accuracies) for all configs where the # epochs is 30, the batch size is 10, the cost function is quadratic and the learning rate is variable
label_learningrate = []
tt_learningrate = []
acc_learningrate = []
for i, config in enumerate(configs):
  if config[0] == 30 and config[1] == 10:
    label_learningrate.append(labelsSingle[2*i])
    tt_learningrate.append(training_timesSingle[2*i]) # 2i ... b/c we are storing two times for every config ... +1 b/c it's the second one that we want (i.e., the quadratic cost function)
    acc_learningrate.append(accuraciesSingle[2*i]) # 2i ... b/c we are storing two times for every config ... +1 b/c it's the second one that we want (i.e., the quadratic cost function)

print(label_learningrate)
print(tt_learningrate)
print(acc_learningrate)

plt.subplots(figsize=(20,6))
plt.plot(label_learningrate, tt_learningrate)
plt.show()
plt.subplots(figsize=(20,6))
plt.plot(label_learningrate, acc_learningrate)
plt.show
# Out:
# ['[30, 10, 0.1]-cross-784-15-10', '[30, 10, 0.5]-cross-784-15-10', '[30, 10, 1.0]-cross-784-15-10', '[30, 10, 3.0]-cross-784-15-10', '[30, 10, 5.0]-cross-784-15-10']
# [0.05787014961242676, 0.06134438514709473, 0.052098989486694336, 0.09795522689819336, 0.06182527542114258]
# [2, 5, 6, 7, 5]
# <function matplotlib.pyplot.show(*args, **kw)>
